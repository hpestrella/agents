# %% [markdown]
# # Bienvenido al comienzo de tu aventura en Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#ff7800;">¿Listo para la acción?</h2>
# <span style="color:#ff7800;">¿Has completado todos los pasos de configuración en la carpeta <a href="../setup/">setup</a>?<br/>
#
# ¿Has consultado las guías en la carpeta <a href="../guides/01_intro.ipynb">guides</a>?<br/>
#
# En ese caso, ¡estás listo! </span>
# </td>
# </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#00bfff;">Este código es un recurso activo; esté atento a mis actualizaciones</h2>
# <span style="color:#00bfff;">Actualizo periódicamente. A medida que los usuarios hacen preguntas o tienen problemas, añado más ejemplos y mejoro las explicaciones. Por lo tanto, es posible que el código a continuación no sea idéntico al de los vídeos, ya que he añadido más pasos y mejores comentarios. Considérelo como un libro interactivo que acompaña a las clases.<br/><br/>
# Intento enviar correos electrónicos regularmente con actualizaciones importantes relacionadas con el curso. Puedes encontrarlo en la sección "Anuncios" de Udemy, en la barra lateral izquierda. También puedes optar por recibir mis correos electrónicos a través de la configuración de notificaciones en Udemy. Soy respetuoso con tu bandeja de entrada y siempre intento aportar valor con mis correos.
#
# </span>
# </td>
# </tr>
# </table>

# %% [markdown]
# ### Y por favor, recuerda contactarme si puedo ayudarte.
#
# Me encantaría conectar contigo: https://www.linkedin.com/in/juan-gabriel-gomila-salas/
#
# ### ¿Eres nuevo en Notebooks como este? ¡Visita la carpeta de guías!
#
# Para comprobar que ya has añadido las extensiones de Python y Jupyter a Cursor, si aún no las tienes instaladas:
# - Abre Extensiones (Ver >> Extensiones).
# - Busca Python y, cuando aparezcan los resultados, haz clic en la de ms-python e instálala si aún no está instalada.
# - Busca Jupyter y, cuando aparezcan los resultados, haz clic en la de Microsoft e instálala si aún no está instalada.
# Luego, ve a Ver >> Explorador para volver al Explorador de archivos.
#
# Y luego:
# 1. Haz clic donde dice "Seleccionar Kernel" cerca de la esquina superior derecha y selecciona la opción `.venv (Python 3.12.9)` o similar, que debería ser la primera opción o la más destacada. Quizás primero debas seleccionar "Entornos de Python".
# 2. Haz clic en cada celda a continuación, comenzando por la celda inmediatamente inferior a este texto, y presiona Mayús+Intro para ejecutar.
# 3. ¡Disfruta!
#
# Después de hacer clic en "Seleccionar Kernel", si no hay ninguna opción como `.venv (Python 3.12.9)`, haz lo siguiente:
# 1. En Mac: En el menú Cursor, selecciona Configuración >> Configuración de VS Code (NOTA: asegúrate de seleccionar `Configuración de VSCode`, no `Configuración de Cursor`). En una PC con Windows: En el menú Archivo, seleccione Preferencias >> Configuración de VS Code (NOTA: asegúrate de seleccionar "Configuración de VS Code" y no "Configuración de Cursor").
# 2. En la barra de búsqueda de Configuración, escriba "venv".
# 3. En el campo "Ruta a la carpeta con la lista de entornos virtuales", introduzca la ruta a la raíz del proyecto, como C:\Users\username\projects\agents (en una PC con Windows) o /Users/username/projects/agents (en Mac o Linux).
# Inténtelo de nuevo.
#
# ¿Tiene problemas porque faltan versiones de Python en la lista? ¿Ha usado Anaconda anteriormente? Podría estar interfiriendo. Salga de Cursor, abra una nueva línea de comandos y asegúrese de que su entorno de Anaconda esté desactivado: `conda deactivate`
# Si aún tiene problemas con las versiones de Conda y Python, es posible que también deba ejecutar esto: `conda config --set auto_activate_base false`
# Y luego, desde el directorio Agentes, debería poder ejecutar `uv python list` y ver la versión de Python 3.12.

# %%
# Empecemos por hacer un import
from dotenv import load_dotenv

# %%
# A continuación, es el momento de cargar las claves API en las variables de entorno.

load_dotenv(override=True)
# Out:
# True

# %%
# Comprobamos las claves

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"La clave API de OpenAI existe y empieza por {openai_api_key[:8]}")
else:
    print("La clave API de OpenAI no existe - Dirígete a la guía de solución de problemas en la carpeta de configuración.")
# Out:
# La clave API de OpenAI existe y empieza por sk-proj-

# %%
# Y ahora, la importante declaración de importación
# Si recibes un error de importación, consulta la guía de solución de problemas

from openai import OpenAI

# %%
# Ahora crearemos una instancia de la clase OpenAI.
# Si no estás seguro de lo que significa crear una instancia de una clase, ¡visita la carpeta de guías!
# Si recibes un error de nombre, visita la carpeta de guías para obtener más información sobre los errores de nombre.

openai = OpenAI()

# %%
# Crea una lista de mensajes en el formato familiar de OpenAI

messages = [{"role": "user", "content": "¿Cuanto es 2+2?"}]

# %%
# ¡Y ahora, a llamarlo! Si tienes algún problema, consulta la guía de solución de problemas.
# Usa GPT 4.1 nano, el modelo increíblemente económico.

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 es igual a 4.

# %%
# Y ahora, vamos a llamar a la API de OpenAI

question = "Proponga una pregunta difícil y desafiante para evaluar el coeficiente intelectual de alguien. Responde únicamente con la pregunta."
messages = [{"role": "user", "content": question}]

# %%
# Pregúntale: usa GPT 4.1 mini, aún barato pero más potente que nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# Si en un reloj analógico el ángulo entre las manecillas de la hora y los minutos es exactamente 90 grados a las 3 en punto, ¿a qué hora, entre las 2 y las 4, ocurre exactamente lo mismo de nuevo? Explica el razonamiento.

# %%
# una nueva lista de mensajes
messages = [{"role": "user", "content": question}]

# %%
# Hacemos una nueva pregunta

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# ¡Claro! Vamos a analizar el problema paso a paso.
#
# ---
#
# ### Datos y explicación inicial
#
# - En un reloj analógico, las manecillas forman ángulos variables a lo largo del tiempo.
# - Se nos dice que a las **3 en punto** (3:00:00), el ángulo entre la manecilla de la hora y la de los minutos es **90 grados**.
#
# Queremos saber **a qué hora, entre las 2 y las 4, ocurre nuevamente un ángulo de 90 grados entre las manos del reloj**.
#
# ---
#
# ### Paso 1: Comprender el movimiento de las manecillas
#
# - Cada hora, la manecilla de la **hora** avanza **30 grados** (360° / 12 horas).
# - Por minuto, la manecilla de la hora avanza:
#
#   \[
#   30^\circ / 60 = 0.5^\circ \text{ por minuto}
#   \]
#
# - La manecilla de los minutos avanza:
#
#   \[
#   360^\circ / 60 = 6^\circ \text{ por minuto}
#   \]
#
# ---
#
# ### Paso 2: Definir la variable de tiempo
#
# Sea \( t \) el número de minutos después de las 2:00.
#
# Entonces, la posición de las manecillas será:
#
# - Ángulo manecilla de la hora, respecto a las 12 horas (en grados):
#
# \[
# H = 60^\circ + 0.5t
# \]
#
# > Porque a las 2:00 la manecilla de la hora está en \( 2 \times 30^\circ = 60^\circ \).
#
# - Ángulo manecilla de los minutos:
#
# \[
# M = 6t
# \]
#
# ---
#
# ### Paso 3: Encontrar \( t \) cuando el ángulo es 90 grados
#
# El ángulo entre las manecillas es el valor absoluto de la diferencia entre \( H \) y \( M \), pero como el ángulo más pequeño es lo que buscamos (ángulo menor o igual a 180 grados), el ángulo real es:
#
# \[
# \theta = \min\big(|H - M|, 360 - |H - M|\big)
# \]
#
# Para nuestro caso, asumimos que estamos buscando cuando:
#
# \[
# \theta = 90^\circ
# \]
#
# Es decir:
#
# \[
# |H - M| = 90 \quad \text{o} \quad |H - M| = 270
# \]
#
# Pero el ángulo interior más pequeño será el que busquemos, y 270 equivale a 90 para la manecilla opuesta, así que podemos usar solo \( |H - M| = 90 \), considerando que si \( |H - M| > 180 \) tomaremos \( 360 - |H - M| \).
#
# Entonces:
#
# \[
# |60 + 0.5t - 6t| = 90
# \]
# \[
# |60 - 5.5t| = 90
# \]
#
# Esto da dos ecuaciones:
#
# 1. \(60 - 5.5t = 90\)
# 2. \(60 - 5.5t = -90\)
#
# ---
#
# ### Paso 4: Resolver para \( t \)
#
# Para la ecuación 1:
#
# \[
# 60 - 5.5t = 90 \Rightarrow -5.5t = 30 \Rightarrow t = -\frac{30}{5.5} = -5.4545... \quad \text{(no válido, porque es antes de las 2:00)}
# \]
#
# Para la ecuación 2:
#
# \[
# 60 - 5.5t = -90 \Rightarrow -5.5t = -150 \Rightarrow t = \frac{150}{5.5} = 27.2727... \text{ minutos}
# \]
#
# ---
#
# ### Paso 5: Verificar la solución dentro del rango pedido (entre las 2 y las 4)
#
# Entre las 2 y las 4 son 120 minutos (2 horas), \( t \) es de 0 a 120.
#
# \[
# t = 27.2727 \text{ minutos } \approx 27 \text{ minutos } 16 \text{ segundos}
# \]
#
# Esto es aproximadamente las **2:27:16**, y cumple con ser después de las 2:00 y antes de las 3:00.
#
# ---
#
# ### Paso 6: Comprobar si hay otra solución entre las 3 y 4
#
# Recordemos que a las 3:00 la diferencia es ya 90°, como dice el enunciado. Entonces, podemos repetir el procedimiento con \( t \) contado desde las 3:00 para hallar otra ocasión antes de las 4:00 (si se desea).
#
# Por curiosidad, perfecto; pero la pregunta es a qué hora **entre las 2 y las 4** ocurre **de nuevo** (justo después de las 3 en punto), entonces la única solución para \( t \in (0,60) \) es la calculada.
#
# ---
#
# ### **Respuesta final:**
#
# El siguiente momento, entre las 2 y las 4, en que las manecillas del reloj forman un ángulo exacto de **90 grados** después de las 3 en punto es a las:
#
# \[
# 2:27:16 \quad (\text{o } 2 \text{ horas, } 27 \text{ minutos, } 16 \text{ segundos})
# \]
#
# ---
#
# ### **Resumen breve:**
#
# 1. Planteamos los ángulos de las manecillas respecto a las 12 horas como función del tiempo \( t \) en minutos después de las 2.
# 2. Buscamos cuando la diferencia de horarios es 90 grados.
# 3. Resolvimos la ecuación para \( t \).
# 4. Obtenemos \( t \approx 27.27 \) minutos.
# 5. La hora es 2:27:16, que es el siguiente instante entre las 2 y las 4 con ángulo de 90 grados entre las manecillas.
#
# ---
#
# Si necesitas, puedo ayudarte a verificar el valor exacto o calcular más momentos similares. ¿Quieres?

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# ¡Claro! Vamos a analizar el problema paso a paso.
#
# ---
#
# ### Datos y explicación inicial
#
# - En un reloj analógico, las manecillas forman ángulos variables a lo largo del tiempo.
# - Se nos dice que a las **3 en punto** (3:00:00), el ángulo entre la manecilla de la hora y la de los minutos es **90 grados**.
#
# Queremos saber **a qué hora, entre las 2 y las 4, ocurre nuevamente un ángulo de 90 grados entre las manos del reloj**.
#
# ---
#
# ### Paso 1: Comprender el movimiento de las manecillas
#
# - Cada hora, la manecilla de la **hora** avanza **30 grados** (360° / 12 horas).
# - Por minuto, la manecilla de la hora avanza:
#
#   \[
#   30^\circ / 60 = 0.5^\circ \text{ por minuto}
#   \]
#
# - La manecilla de los minutos avanza:
#
#   \[
#   360^\circ / 60 = 6^\circ \text{ por minuto}
#   \]
#
# ---
#
# ### Paso 2: Definir la variable de tiempo
#
# Sea \( t \) el número de minutos después de las 2:00.
#
# Entonces, la posición de las manecillas será:
#
# - Ángulo manecilla de la hora, respecto a las 12 horas (en grados):
#
# \[
# H = 60^\circ + 0.5t
# \]
#
# > Porque a las 2:00 la manecilla de la hora está en \( 2 \times 30^\circ = 60^\circ \).
#
# - Ángulo manecilla de los minutos:
#
# \[
# M = 6t
# \]
#
# ---
#
# ### Paso 3: Encontrar \( t \) cuando el ángulo es 90 grados
#
# El ángulo entre las manecillas es el valor absoluto de la diferencia entre \( H \) y \( M \), pero como el ángulo más pequeño es lo que buscamos (ángulo menor o igual a 180 grados), el ángulo real es:
#
# \[
# \theta = \min\big(|H - M|, 360 - |H - M|\big)
# \]
#
# Para nuestro caso, asumimos que estamos buscando cuando:
#
# \[
# \theta = 90^\circ
# \]
#
# Es decir:
#
# \[
# |H - M| = 90 \quad \text{o} \quad |H - M| = 270
# \]
#
# Pero el ángulo interior más pequeño será el que busquemos, y 270 equivale a 90 para la manecilla opuesta, así que podemos usar solo \( |H - M| = 90 \), considerando que si \( |H - M| > 180 \) tomaremos \( 360 - |H - M| \).
#
# Entonces:
#
# \[
# |60 + 0.5t - 6t| = 90
# \]
# \[
# |60 - 5.5t| = 90
# \]
#
# Esto da dos ecuaciones:
#
# 1. \(60 - 5.5t = 90\)
# 2. \(60 - 5.5t = -90\)
#
# ---
#
# ### Paso 4: Resolver para \( t \)
#
# Para la ecuación 1:
#
# \[
# 60 - 5.5t = 90 \Rightarrow -5.5t = 30 \Rightarrow t = -\frac{30}{5.5} = -5.4545... \quad \text{(no válido, porque es antes de las 2:00)}
# \]
#
# Para la ecuación 2:
#
# \[
# 60 - 5.5t = -90 \Rightarrow -5.5t = -150 \Rightarrow t = \frac{150}{5.5} = 27.2727... \text{ minutos}
# \]
#
# ---
#
# ### Paso 5: Verificar la solución dentro del rango pedido (entre las 2 y las 4)
#
# Entre las 2 y las 4 son 120 minutos (2 horas), \( t \) es de 0 a 120.
#
# \[
# t = 27.2727 \text{ minutos } \approx 27 \text{ minutos } 16 \text{ segundos}
# \]
#
# Esto es aproximadamente las **2:27:16**, y cumple con ser después de las 2:00 y antes de las 3:00.
#
# ---
#
# ### Paso 6: Comprobar si hay otra solución entre las 3 y 4
#
# Recordemos que a las 3:00 la diferencia es ya 90°, como dice el enunciado. Entonces, podemos repetir el procedimiento con \( t \) contado desde las 3:00 para hallar otra ocasión antes de las 4:00 (si se desea).
#
# Por curiosidad, perfecto; pero la pregunta es a qué hora **entre las 2 y las 4** ocurre **de nuevo** (justo después de las 3 en punto), entonces la única solución para \( t \in (0,60) \) es la calculada.
#
# ---
#
# ### **Respuesta final:**
#
# El siguiente momento, entre las 2 y las 4, en que las manecillas del reloj forman un ángulo exacto de **90 grados** después de las 3 en punto es a las:
#
# \[
# 2:27:16 \quad (\text{o } 2 \text{ horas, } 27 \text{ minutos, } 16 \text{ segundos})
# \]
#
# ---
#
# ### **Resumen breve:**
#
# 1. Planteamos los ángulos de las manecillas respecto a las 12 horas como función del tiempo \( t \) en minutos después de las 2.
# 2. Buscamos cuando la diferencia de horarios es 90 grados.
# 3. Resolvimos la ecuación para \( t \).
# 4. Obtenemos \( t \approx 27.27 \) minutos.
# 5. La hora es 2:27:16, que es el siguiente instante entre las 2 y las 4 con ángulo de 90 grados entre las manecillas.
#
# ---
#
# Si necesitas, puedo ayudarte a verificar el valor exacto o calcular más momentos similares. ¿Quieres?

# %% [markdown]
# # ¡Felicidades!
#
# ¡Ese fue un pequeño y sencillo paso hacia la IA Agentic con tu nuevo entorno!
#
# La próxima vez que las cosas se pongan más interesantes...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#ff7800;">Ejercicio</h2>
# <span style="color:#ff7800;">Ahora, prueba esta aplicación comercial:<br/>
# Primero, pide al LLM que elija un área de negocio que valga la pena explorar para una oportunidad de IA con Agentic.<br/>
# Después, pide al LLM que presente un problema en esa industria, algo desafiante que pueda ser propicio para una solución con Agentic.<br/>
# Finalmente, pide a la tercera convocatoria del LLM que proponga la solución de IA con Agentic. </span>
# </td>
# </tr>
# </table>

# %%
# Priemro creamos el mensaje

messages = [{"role": "user", "content": "Elige dentro del Area de Datos un Problema" }]

# Hacemos la primera llamada:

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Claro, dentro del área de Datos uno de los problemas más comunes y relevantes es:
#
# **Problema: Calidad y limpieza de datos insuficiente**
#
# Muchos proyectos de análisis de datos, machine learning o inteligencia artificial enfrentan grandes dificultades debido a que los datos disponibles están incompletos, contienen errores, valores duplicados, inconsistencias o están desactualizados. Esto afecta la fiabilidad de los modelos y decisiones basadas en esos datos.
#
# Si quieres, puedo ayudarte a profundizar en este problema, explorar sus causas, o proponerte soluciones y técnicas para abordarlo. ¿Te interesa?

# %%
# Y ahora, vamos a llamar a la API de OpenAI

question = "Ayudame con una solución Agentica para resolver el problema de Calidad y limpieza de datos insuficiente"
messages = [{"role": "user", "content": question}]

# %%
# Luego leemos la idea de negocio:

# Hacemos la primera llamada:

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)


business_idea = response.choices[0].message.content
print(business_idea)

# Y repetimos!
# Out:
# Claro, te puedo ayudar a plantear una solución **agentica** (basada en agentes inteligentes) para mejorar la calidad y limpieza de datos insuficiente. Este tipo de solución utiliza agentes de software autónomos que trabajan de manera coordinada para identificar, corregir y mantener la calidad de los datos.
#
# ---
#
# ## Solución Agentica para Calidad y Limpieza de Datos
#
# ### 1. **Patrón General: Sistema Multiagente para Calidad de Datos**
#
# Se crea un sistema compuesto por diferentes agentes especializados que colaboran para detectar y corregir problemas en los datos, así como para monitorear continuamente la calidad.
#
# ---
#
# ### 2. **Agentes Participantes y Funciones**
#
# - **Agente de Detección**
#   - Identifica anomalías, datos faltantes, inconsistencias o duplicados.
#   - Aplica reglas predefinidas y técnicas de aprendizaje automático para detectar errores.
#   - Señala la calidad según indicadores (completitud, validez, consistencia, unicidad, etc).
#
# - **Agente de Limpieza**
#   - Corrige automáticamente los errores detectados: rellena valores faltantes, corrige formatos, elimina duplicados, estandariza datos, etc.
#   - Utiliza reglas de negocio y algoritmos de imputación o transformación.
#   - Solicita interacción humana para casos ambiguos o críticos.
#
# - **Agente de Validación**
#   - Verifica que las correcciones se hayan aplicado correctamente.
#   - Monitoriza que los datos se mantengan dentro de los estándares definidos.
#   - Informa si detecta problemas residuales o nuevos errores.
#
# - **Agente de Aprendizaje y Mejora**
#   - Aprende de los errores detectados y las correcciones aplicadas.
#   - Actualiza reglas y modelos para mejorar la detección y limpieza futura.
#   - Ajusta umbrales y parámetros de calidad.
#
# - **Agente de Reportes y Notificaciones**
#   - Genera informes periódicos sobre la calidad de los datos.
#   - Envía alertas y recomendaciones a responsables humanos.
#   - Facilita auditorías y toma de decisiones.
#
# ---
#
# ### 3. **Flujo de Trabajo**
#
# 1. El **Agente de Detección** analiza los datos entrantes o almacenados.
# 2. Identifica problemas de calidad y los etiqueta.
# 3. El **Agente de Limpieza** lee estas etiquetas y realiza correcciones automáticas o solicita revisión humana.
# 4. Correcciones aplicadas se validan por el **Agente de Validación**.
# 5. El **Agente de Aprendizaje** ajusta sus modelos y reglas con base en la experiencia para mejorar futuros procesos.
# 6. El **Agente de Reportes** informa a los usuarios y gestores de datos.
#
# ---
#
# ### 4. **Tecnologías y Técnicas sugeridas**
#
# - **Reglas de negocio y ontologías** para normalizar y validar datos.
# - **Machine Learning/IA** para detección avanzada de anomalías y predicción de valores faltantes.
# - **Agentes inteligentes** programados en plataformas como JADE, SPADE o cualquier framework multiagente.
# - **Bases de datos con soporte de calidad** y herramientas ETL inteligentes.
# - **Interfaces para interacción humana**, donde el agente solicite confirmación en casos complejos.
#
# ---
#
# ### 5. **Beneficios**
#
# - Mejora continua de la calidad de datos.
# - Reducción de errores humanos en procesos manuales.
# - Capacidad de adaptación a nuevos tipos y fuentes de datos.
# - Reportes automáticos para control y auditoría.
# - Escalabilidad y modularidad gracias a la arquitectura multiagente.
#
# ---
#
# ¿Quieres que te ayude con un diseño específico en código, elegir tecnologías o un ejemplo concreto para tu problema?
